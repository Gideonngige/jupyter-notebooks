# %%
# import libraries
from datetime import datetime
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
import seaborn as sns
# Out:
# 2026-02-16 11:01:12.493668: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-16 11:01:18.193282: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-16 11:01:33.780639: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Read the data
microsoft = pd.read_csv('datasets/MicrosoftStock.csv', usecols=lambda col : col != 'index')
print(microsoft.head())
# Out:
#          date   open   high    low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
# shape of the data
microsoft.shape
# Out:
# (1259, 7)

# %%
# info
microsoft.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   str
#  1   open    1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   close   1259 non-null   float64
#  5   volume  1259 non-null   int64
#  6   Name    1259 non-null   str
# dtypes: float64(4), int64(1), str(2)
# memory usage: 69.0 KB

# %%
microsoft.describe()
# Out:
#               open         high          low        close        volume
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean     51.026394    51.436007    50.630397    51.063081  3.386946e+07
# std      14.859387    14.930144    14.774630    14.852117  1.958979e+07
# min      27.350000    27.600000    27.230000    27.370000  7.425603e+06
# 25%      40.305000    40.637500    39.870000    40.310000  2.254879e+07
# 50%      47.440000    47.810000    47.005000    47.520000  2.938758e+07
# 75%      59.955000    60.435000    59.275000    59.730000  3.842024e+07
# max      95.140000    96.070000    93.720000    95.010000  2.483542e+08

# %%
microsoft['date'] = pd.to_datetime(microsoft['date'])
plt.plot(microsoft['date'], microsoft['open'], color="blue", label="open")
plt.plot(microsoft['date'], microsoft['close'], color="green", label="close")
plt.title("Microsoft Open-Close Stock")
plt.legend()

# %%
plt.plot(microsoft['date'], microsoft['volume'])
plt.show()

# %%
sns.heatmap(microsoft.select_dtypes(include=np.number).corr(), 
			annot=True, 
			cbar=False) 
plt.show()

# %%
microsoft['date'] = pd.to_datetime(microsoft['date'])
prediction = microsoft.loc[(microsoft['date'] > datetime(2013, 1, 1)) & (microsoft['date'] < datetime(2018, 1, 1))]

plt.figure(figsize=(10, 10))
plt.plot(microsoft['date'], microsoft['close'])
plt.xlabel('Date')
plt.ylabel("Close")
plt.title("Microsoft Stock Prices")
# Out:
# Text(0.5, 1.0, 'Microsoft Stock Prices')

# %%
# prepare the training set samples
msft_close = microsoft.filter(['close'])
dataset = msft_close.values
training = int(np.ceil(len(dataset) * .95))

# %%
# scaling the data
ss = StandardScaler()
ss = ss.fit_transform(dataset)

train_data = ss[0: int(training), :]

x_train = []
y_train = []

# creating X_train and y_train
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)
X_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# model
model = keras.models.Sequential()
model.add(keras.layers.LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(keras.layers.LSTM(units=64))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1))

print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,985 (195.25 KB)
#  Trainable params: 49,985 (195.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# compile and fit 
from keras.metrics import RootMeanSquaredError
model.compile(optimizer='adam', loss='mae', metrics=[RootMeanSquaredError()])

history = model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.2201 - root_mean_squared_error: 0.3372
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.1221 - root_mean_squared_error: 0.1676
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.1182 - root_mean_squared_error: 0.1577
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.1088 - root_mean_squared_error: 0.1471
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.1083 - root_mean_squared_error: 0.1483
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.1162 - root_mean_squared_error: 0.1602
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.1062 - root_mean_squared_error: 0.1459
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1042 - root_mean_squared_error: 0.1439
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.1057 - root_mean_squared_error: 0.1420
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1068 - root_mean_squared_error: 0.1438
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.1048 - root_mean_squared_error: 0.1432
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0982 - root_mean_squared_error: 0.1321
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.1036 - root_mean_squared_error: 0.1423
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1007 - root_mean_squared_error: 0.1371
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.1022 - root_mean_squared_error: 0.1365
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.1045 - root_mean_squared_error: 0.1442
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0993 - root_mean_squared_error: 0.1370
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0970 - root_mean_squared_error: 0.1328
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0991 - root_mean_squared_error: 0.1362
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.1005 - root_mean_squared_error: 0.1373

# %%
# model evaluation
testing = ss[training - 60:, :]
x_test = []
y_test = dataset[training:, :]
for i in range(60, len(testing)):
    x_test.append(testing[i-60:i,0])

x_test = np.array(x_test)
X_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

pred = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step

# %%
train = microsoft[:training]
test = microsoft[training:]
test['Predictions'] = pred

plt.figure(figsize=(10, 8))
plt.plot(train['close'], c="b")
plt.plot(test[['close', 'Predictions']])
plt.title('Microsoft Stock Close Price')
plt.ylabel("Close")
plt.legend(['Train', 'Test', 'Predictions'])
