# %%
import pandas as pd

crop_requirements = pd.DataFrame({

    "Crop": [
        "Apples",
        "Arrow Root",
        "Avocado",
        "Banana (Cooking)",
        "Banana (Plantain)",
        "Banana (Ripening)",
        "Beans (Canadian wonder)",
        "Beans (Mwezi Moja)",
        "Beans (Mwitemania)",
        "Beans Red Haricot (Wairimu)",
        "Beans (Rosecoco)",
        "Beans Rosecoco (Nyayo)",
        "Beans (Yellow-Green)",
        "Cabbages",
        "Carrots",
        "Cashewnuts (Korosho)",
        "Cassava Chips (dry)",
        "Cassava Fresh",
        "Coconut",
        "Coffee",
        "Cotton",
        "Cowpeas",
        "Cucumber",
        "Dolichos lablab (Njahi)",
        "Dry Onions",
        "Dry Peas",
        "Egg plant (Brinjals)",
        "Finger Millet",
        "French beans",
        "Fresh Peas",
        "Garlic",
        "Ginger",
        "Grapes",
        "Green Grams",
        "Green Maize",
        "Ground Nuts",
        "Kales/Sukuma Wiki",
        "Lemons",
        "Limes",
        "Macadamia Seed",
        "Dry Maize",
        "Mangoes",
        "Njugu Mawe",
        "Oranges",
        "Passion Fruits",
        "Pawpaw",
        "Pearl Rush Millet",
        "Pigeon peas",
        "Pineapples",
        "Pumpkin",
        "Red Irish potato",
        "Red Sorghum",
        "Rice",
        "Spinach",
        "Spring Onions",
        "Sweet potatoes",
        "Tea",
        "Tomatoes",
        "Water Melon",
        "Wheat",
        "White Irish Potatoes",
        "White Sorghum",
        "Yam"
    ],

    # Temperature in °C
    "Min_Temp": [18, 16, 20, 10, 20, 15, 18, 13, 16, 15, 10],
    "Max_Temp": [30, 28, 35, 25, 35, 22, 30, 24, 28, 24, 20],

    # Annual Rainfall in mm
    "Min_Rain": [500, 400, 1000, 500, 300, 600, 600, 500, 500, 1200, 1200],
    "Max_Rain": [800, 700, 2000, 1200, 800, 1200, 1200, 1000, 1000, 2000, 2500],

    # Soil pH Range
    "Min_pH": [5.5, 6.0, 5.0, 6.0, 5.0, 5.0, 5.5, 6.0, 5.5, 6.0, 4.5],
    "Max_pH": [7.5, 7.5, 6.5, 7.5, 7.5, 6.5, 7.5, 7.5, 7.5, 6.5, 5.5]
})

# print(crop_requirements)
crop_requirements.to_csv("crop_requirements.csv", index=False)
